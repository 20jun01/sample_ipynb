# %% [markdown]
# # Usage
# ## すべてのプログラムを実行する場合(Run all programs)
# ### Google Driveで実行する場合(Run on Google Drive)
# 1. このnotebookをGoogle Driveにアップロードします(Upload this notebook to Google Drive)
# 2. Google Colaboratoryを接続してこのnotebookを開きます(Open this notebook on Google Colab)
# 3. ランタイムからすべてのセルを実行をします。すると、すべてのプログラムが実行されます(Run All cells, then all programs will be executed)
#
# ### ローカルで実行する場合(Run on local)
# 1. このnotebookをダウンロードします(Download this notebook)
# 2. VSCodeなどのエディタで開きます(Open this notebook on VSCode or other editors)
# 3. Run Allを実行します(Run All Cells)
#
# もし必要があれば、以下のライブラリをインストールしてください(If you need, install the following libraries)
# requirements.txtにも記載されています(They are also written in requirements.txt)
# ```python
# pip install jupyter
# pip install pykernel
# pip install pytest
# ```
# また、jupyterの拡張機能をVSCodeにインストールしてください(Also, install jupyter extension on VSCode)
#
# ## 一部のプログラムを実行する場合(Run part of programs)
# 実行以外は上記と同じです(same as above except Run All)
# 1. 実行したいセルの左側に▷マーク(実行マーク)が表示されているので、それをクリックします(Click ▷ mark on the left side of the cell you want to run)
#
# ## 共通の注意事項(Notes)
# もし、Installがうまく動かなかった場合は対象のライブラリをインストールしてください(If Install doesn't work, install the target library)
# 動かすだけなら、インストールしなくてもRunは動きます(If you just want to run, you don't need to install libraries)

# %% [markdown]
# # 動作確認(Health)
# もし、正常に環境が構築されていれば、以下の実行が成功し1が表示されます(If the environment is set up correctly, the following execution will succeed and 1 will be displayed)

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # Install

# %%
# %pip install pytest-ipynb
# %pip install pytest
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytest-ipynb
#   Downloading pytest-ipynb-1.1.1.tar.gz (3.7 kB)
# Collecting pytest
#   Downloading pytest-7.2.1-py3-none-any.whl (317 kB)
#      |████████████████████████████████| 317 kB 1.3 MB/s eta 0:00:01
# Collecting runipy
#   Downloading runipy-0.1.5.tar.gz (24 kB)
# Requirement already satisfied: packaging in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from pytest->pytest-ipynb) (23.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from pytest->pytest-ipynb) (22.2.0)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: tomli>=1.0.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from pytest->pytest-ipynb) (2.0.1)
# Requirement already satisfied: Jinja2>=2.7.2 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from runipy->pytest-ipynb) (3.1.2)
# Requirement already satisfied: Pygments>=1.6 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from runipy->pytest-ipynb) (2.14.0)
# Requirement already satisfied: ipython>=2.3.1 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from runipy->pytest-ipynb) (8.10.0)
# Requirement already satisfied: pyzmq>=14.1.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from runipy->pytest-ipynb) (25.0.0)
# Requirement already satisfied: ipykernel>=4.0.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from runipy->pytest-ipynb) (6.21.2)
# Requirement already satisfied: nbconvert>=4.0.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from runipy->pytest-ipynb) (7.2.9)
# Requirement already satisfied: nbformat>=4.0.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from runipy->pytest-ipynb) (5.7.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (0.1.2)
# Requirement already satisfied: appnope in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (0.1.3)
# Requirement already satisfied: tornado>=6.1 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (5.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (1.6.6)
# Requirement already satisfied: psutil in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (5.9.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (8.0.3)
# Requirement already satisfied: nest-asyncio in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (1.5.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (0.1.6)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipykernel>=4.0.0->runipy->pytest-ipynb) (5.9.0)
# Requirement already satisfied: stack-data in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipython>=2.3.1->runipy->pytest-ipynb) (0.6.2)
# Requirement already satisfied: decorator in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipython>=2.3.1->runipy->pytest-ipynb) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipython>=2.3.1->runipy->pytest-ipynb) (3.0.36)
# Requirement already satisfied: backcall in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipython>=2.3.1->runipy->pytest-ipynb) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipython>=2.3.1->runipy->pytest-ipynb) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipython>=2.3.1->runipy->pytest-ipynb) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from ipython>=2.3.1->runipy->pytest-ipynb) (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=2.3.1->runipy->pytest-ipynb) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from Jinja2>=2.7.2->runipy->pytest-ipynb) (2.1.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.0.0->runipy->pytest-ipynb) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.0.0->runipy->pytest-ipynb) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.0.0->runipy->pytest-ipynb) (3.14.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.0.0->runipy->pytest-ipynb) (3.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbconvert>=4.0.0->runipy->pytest-ipynb) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbconvert>=4.0.0->runipy->pytest-ipynb) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbconvert>=4.0.0->runipy->pytest-ipynb) (0.7.2)
# Requirement already satisfied: bleach in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbconvert>=4.0.0->runipy->pytest-ipynb) (6.0.0)
# Requirement already satisfied: defusedxml in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbconvert>=4.0.0->runipy->pytest-ipynb) (0.7.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbconvert>=4.0.0->runipy->pytest-ipynb) (2.0.5)
# Requirement already satisfied: beautifulsoup4 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbconvert>=4.0.0->runipy->pytest-ipynb) (4.11.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbconvert>=4.0.0->runipy->pytest-ipynb) (0.2.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbformat>=4.0.0->runipy->pytest-ipynb) (4.17.3)
# Requirement already satisfied: fastjsonschema in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from nbformat>=4.0.0->runipy->pytest-ipynb) (2.16.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.0.0->runipy->pytest-ipynb) (0.19.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=2.3.1->runipy->pytest-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=2.3.1->runipy->pytest-ipynb) (0.2.6)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.0.0->runipy->pytest-ipynb) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert>=4.0.0->runipy->pytest-ipynb) (2.4)
# Requirement already satisfied: webencodings in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from bleach->nbconvert>=4.0.0->runipy->pytest-ipynb) (0.5.1)
# Requirement already satisfied: pure-eval in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=2.3.1->runipy->pytest-ipynb) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=2.3.1->runipy->pytest-ipynb) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/midorikawajun/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=2.3.1->runipy->pytest-ipynb) (1.2.0)
# Building wheels for collected packages: pytest-ipynb, runipy
#   Building wheel for pytest-ipynb (setup.py) ... done
#   Created wheel for pytest-ipynb: filename=pytest_ipynb-1.1.1-py3-none-any.whl size=4148 sha256=eab490c0699bd69711a972441b86564d2aa404c942bf44e9f0c7023379b0b94b
#   Stored in directory: /Users/midorikawajun/Library/Caches/pip/wheels/1a/2e/22/ef4bcd703e8240f7dca6ed6f2e1b9c261a9f7a10aaadb7638a
#   Building wheel for runipy (setup.py) ... done
#   Created wheel for runipy: filename=runipy-0.1.5-py3-none-any.whl size=10150 sha256=ac8b172213afba35d1aac7e8d402644e0422ce7a1b1481ab0d840017e874ce19
#   Stored in directory: /Users/midorikawajun/Library/Caches/pip/wheels/84/0e/9d/5bd783226ef02a59302f3974ea54e46181a09eec78f67d058c
# Successfully built pytest-ipynb runipy
# Installing collected packages: pluggy, iniconfig, exceptiongroup, runipy, pytest, pytest-ipynb
#   WARNING: The script runipy is installed in '/Users/midorikawajun/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The scripts py.test and pytest are installed in '/Users/midorikawajun/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
# Successfully installed exceptiongroup-1.1.0 iniconfig-2.0.0 pluggy-1.0.0 pytest-7.2.1 pytest-ipynb-1.1.1 runipy-0.1.5
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Code
# ## 仕様(Specification)
# 以下のような条件を満たすこと。
# - ある時刻と、時間の範囲(開始時刻と終了時刻)を受け取る。
# - 時刻は、6時であれば6のような指定でよく、分単位は問わない。
# - 範囲指定は、開始時刻を含み、終了時刻は含まないと判断すること。
# - ただし開始時刻と終了時刻が同じ場合は含むと判断すること。
# - 開始時刻が22時で終了時刻が5時、というような指定をされても動作すること。

# %% [markdown]
# ## How to use
# 1. プログラムを実行すると、以下のような入力を求められるので、入力してください。
# - 時刻を入力してください。(Please enter the time)
# - 開始時刻と終了時刻を入力してください。(Please enter the start time and end time)
# 2. 結果が表示されます。(The result will be displayed)
# Trueが含む、Falseが含まないに対応しています。(True means include, False means not include)
# ## 例(Example)
# ### 例1(Example1)
# - input: 6
# - input time range: 5-7
# - output: True

# %%
import pytest

def check_time(time: int) -> bool:
    """Check if a time is valid.
    Args:
        time (int): Time to check.
    Returns:
        bool: True if time is valid, False otherwise.
    """
    if time > 23 or time < 0:
        return False
    else:
        return True

def validate_time(time: int) -> None:
    """Validate a time.
    Args:
        time (int): Time to validate.
    Raises:
        TypeError: If time is not an integer.
        ValueError: If time is not between 0 and 23.
    """
    if not isinstance(time, int):
        raise TypeError("Time must be an integer.")
    if check_time(time) == False:
        raise ValueError("Time must be between 0 and 23.")

def validate_time_range(time_range: tuple) -> None:
    """Validate a time range.
    Args:
        time_range (tuple): Time range to validate.
    Raises:
        TypeError: If time range is not a tuple.
        TypeError: If time range is not a tuple of integers.
        ValueError: If time range is not a tuple of two values.
        ValueError: If time range is not between 0 and 23.
    """
    if not isinstance(time_range, tuple):
        raise TypeError("Time range must be a tuple.")
    if len(time_range) != 2:
        raise ValueError("Time range must be a tuple of two values.")
    validate_time(time_range[0])
    validate_time(time_range[1])

def is_time_in_range(time: int, time_range: tuple) -> bool:
    """Check if a time is in a time range.
    Args:
        time (int): Time to check.
        time_range (tuple): Time range to check.
    Returns:
        bool: True if time is in time range, False otherwise.
    """

    """Validate input."""
    validate_time(time)
    validate_time_range(time_range)

    """Check if time is in time range."""
    if time_range[0] == time_range[1]:
        return True
    if time_range[0] <= time_range[1]:
        return time_range[0] <= time < time_range[1]
    else:
        return time_range[0] <= time or time < time_range[1]

# %%
def parse_time(time: str) -> int:
    """Parse a time string to an integer.
    Args:
        time (str): Time string to parse.
    Returns:
        int: Parsed time.
    """
    time = time.strip()
    if time.isdigit():
        return int(time)
    else:
        raise ValueError("Time must be an integer.(In parse_time)")

time, time_range = input("input time: "), input("input time range: ")

time = parse_time(time)
time_range = tuple(map(parse_time, time_range.split("-")))

ans = is_time_in_range(time, time_range)

print(ans)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 19
#      16 time = parse_time(time)
#      17 time_range = tuple(map(parse_time, time_range.split("-")))
# ---> 19 ans = is_time_in_range(time, time_range)
#      21 print(ans)
#
# Cell In[19], line 60, in is_time_in_range(time, time_range)
#      58 """Validate input."""
#      59 validate_time(time)
# ---> 60 validate_time_range(time_range)
#      62 """Check if time is in time range."""
#      63 if time_range[0] == time_range[1]:
#
# Cell In[19], line 46, in validate_time_range(time_range)
#      44     raise ValueError("Time range must be a tuple of two values.")
#      45 validate_time(time_range[0])
# ---> 46 validate_time(time_range[1])
#
# Cell In[19], line 28, in validate_time(time)
#      26     raise TypeError("Time must be an integer.")
#      27 if check_time(time) == False:
# ---> 28     raise ValueError("Time must be between 0 and 23.")
#
# ValueError: Time must be between 0 and 23.

# %%
@pytest.mark.timeout(100)
def test_check_time():
    assert check_time(0) == True
    assert check_time(23) == True
    assert check_time(24) == False
    assert check_time(-1) == False

@pytest.mark.timeout(100)
def test_validate_time():
    with pytest.raises(TypeError):
        validate_time("0")
    with pytest.raises(ValueError):
        validate_time(24)
    
@pytest.mark.timeout(100)
def test_validate_time_range():
    with pytest.raises(TypeError):
        validate_time_range([0, 1])
    with pytest.raises(TypeError):
        validate_time_range((0, "1"))
    with pytest.raises(ValueError):
        validate_time_range((0,))
    with pytest.raises(ValueError):
        validate_time_range((0, 24))
    assert validate_time_range((0, 0)) == None

@pytest.mark.timeout(100)
def test_is_time_in_range():
    assert is_time_in_range(0, (0, 0)) == True
    assert is_time_in_range(0, (0, 1)) == True
    assert is_time_in_range(1, (0, 1)) == False
    assert is_time_in_range(0, (1, 0)) == False
    assert is_time_in_range(1, (1, 0)) == True
    assert is_time_in_range(2, (1, 0)) == True

@pytest.mark.timeout(100)
def test_parse_time():
    assert parse_time("0") == 0
    assert parse_time("23") == 23

def test_all():
    test_check_time()
    test_validate_time()
    test_validate_time_range()
    test_is_time_in_range()
    test_parse_time()

if __name__ == "__main__":
    test_all()
